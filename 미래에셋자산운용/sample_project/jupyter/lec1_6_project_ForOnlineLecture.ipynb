# %%
import numpy as np
import pandas as pd

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load data

# %% [markdown]
# - 데이터 출처: 증권사 API, N사 금융, 금투협, 유료 데이터 벤더
# - Section2: 파일 읽는 법, EDA

# %%
# 코드를 돌릴 때 warning이 안나오게 하기
import warnings
warnings.filterwarnings('ignore')

# %%
# 영상에서는 fin_statement_2005_2017.csv이지만(데이터 문제가 있는 파일), 
# 해당 데이터에서 문제를 발견하여, fin_statement_new.csv라는 데이터(2006 ~ )로 대체되었습니다
df = pd.read_csv("../my_data/fin_statement_new.csv")
df.head()
# Out:
#       Code   Name  결산월       상장일              시가총액            유통시가총액  \
# 0  A000020   동화약품   12  19760324  113122453500.000   65520525067.000
# 1  A000040  KR모터스   12  19760525  144125742600.000  111855988832.000
# 2  A000050     경방   12  19560303  275600000000.000  180269960000.000
# 3  A000070  삼양홀딩스   12  19681227  602432236800.000  281576827480.000
# 4  A000100   유한양행   12  19621101 1382097577000.000 1018467704491.000
#
#    P/E(Adj., FY End)  P/B(Adj., FY End)  P/S(Adj., FY End)  \
# 0             11.230              0.550              0.560
# 1             97.070              1.440              0.820
# 2            426.230              0.860              2.010
# 3              8.360              0.570              0.530
# 4             25.280              2.670              4.070
#
#    P/FCF1(Adj., FY End)  EV/EBITDA  EV/EBIT  DPS(보통주, 현금+주식, 연간)  year   수정주가  \
# 0                 4.390      3.480    4.390              600.000  2006   6460
# 1                -7.780     16.840   40.670                0.000  2006   1098
# 2                 5.780     15.340   20.660                0.000  2006  10339
# 3                11.160      4.600    6.210             1050.000  2006  63563
# 4               -27.990     15.720   17.160             1000.000  2006  24911
#
#       ROA        비유동부채          자산총계
# 0   3.810 11961630.000 195293494.000
# 1 -21.980 28190608.000  81250312.000
# 2  -1.800 17344611.000 515345506.000
# 3   5.490 60878366.000 973804019.000
# 4   7.530 95212024.000 746417156.000

# %%
# "12개월전대비수익률(현금배당포함)" 컬럼은 미리 제거하여 파일을 업로드했습니다
df = df.drop(["상장일"], axis=1)
df
# Out:
#           Code        Name  결산월              시가총액            유통시가총액  \
# 0      A000020        동화약품   12  113122453500.000   65520525067.000
# 1      A000040       KR모터스   12  144125742600.000  111855988832.000
# 2      A000050          경방   12  275600000000.000  180269960000.000
# 3      A000070       삼양홀딩스   12  602432236800.000  281576827480.000
# 4      A000100        유한양행   12 1382097577000.000 1018467704491.000
# ...        ...         ...  ...               ...               ...
# 19763  A900290         GRT    6  213915625000.000  131194452813.000
# 19764  A900300    오가닉티코스메틱   12  187283250000.000  104092030350.000
# 19765  A950110  SBI핀테크솔루션즈    3  215744725000.000   59523969628.000
# 19766  A950130      엑세스바이오   12  139925688100.000  102145752313.000
# 19767  A950140       잉글우드랩   12  108279869700.000   67956446224.000
#
#        P/E(Adj., FY End)  P/B(Adj., FY End)  P/S(Adj., FY End)  \
# 0                 11.230              0.550              0.560
# 1                 97.070              1.440              0.820
# 2                426.230              0.860              2.010
# 3                  8.360              0.570              0.530
# 4                 25.280              2.670              4.070
# ...                  ...                ...                ...
# 19763                NaN              0.000                NaN
# 19764              6.520              1.550              1.350
# 19765             22.220              2.790              1.010
# 19766            544.570              2.880              5.100
# 19767           -597.170              3.080              2.140
#
#        P/FCF1(Adj., FY End)  EV/EBITDA   EV/EBIT  DPS(보통주, 현금+주식, 연간)  year  \
# 0                     4.390      3.480     4.390              600.000  2006
# 1                    -7.780     16.840    40.670                0.000  2006
# 2                     5.780     15.340    20.660                0.000  2006
# 3                    11.160      4.600     6.210             1050.000  2006
# 4                   -27.990     15.720    17.160             1000.000  2006
# ...                     ...        ...       ...                  ...   ...
# 19763                   NaN        NaN       NaN               72.000  2017
# 19764                11.960      3.680     3.820               47.000  2017
# 19765                 5.560     -0.210    -0.260                  NaN  2017
# 19766                -8.740     77.250 -1351.730                  NaN  2017
# 19767               -11.380     61.600    81.360                  NaN  2017
#
#         수정주가     ROA        비유동부채          자산총계
# 0       6460   3.810 11961630.000 195293494.000
# 1       1098 -21.980 28190608.000  81250312.000
# 2      10339  -1.800 17344611.000 515345506.000
# 3      63563   5.490 60878366.000 973804019.000
# 4      24911   7.530 95212024.000 746417156.000
# ...      ...     ...          ...           ...
# 19763   3335     NaN          NaN           NaN
# 19764   3030  31.910          NaN           NaN
# 19765   7200   4.220  4972417.000  30428841.000
# 19766   4580   0.590  2134312.000  65728187.000
# 19767   6000  17.610          NaN  26456971.000
#
# [19768 rows x 17 columns]

# %%
df = df.rename(columns={
    "DPS(보통주, 현금+주식, 연간)": "DPS",
    "P/E(Adj., FY End)": "PER",
    "P/B(Adj., FY End)": "PBR",
    "P/S(Adj., FY End)": "PSR",
})

# %%
# 새로 올린 데이터는 2005가 아닌 2006부터 데이터가 존재합니다.
df.groupby(['year'])['Name'].count()
df.groupby(['Name'])['year'].count()
# Out:
# year
# 2006    1479
# 2007    1538
# 2008    1606
# 2009    1636
# 2010    1623
# 2011    1634
# 2012    1653
# 2013    1643
# 2014    1655
# 2015    1692
# 2016    1771
# 2017    1838
# Name: Name, dtype: int64
# Name
# 3S        12
# 3SOFT      4
# 3노드디지탈     6
# AD모터스      7
# AJS        9
#           ..
# 흥국         8
# 흥국에프엔비     2
# 흥아해운      12
# 희림        12
# 희훈디앤지      4
# Name: year, Length: 2241, dtype: int64

# %%
# code or name의 중복 체킹 방법1
df.groupby(['year'])['Name'].nunique().equals(df.groupby(['year'])['Code'].nunique())
# Out:
# True

# %%
# code or name의 중복 체킹 방법2
df.groupby(['year', 'Name'])['Code'].nunique()
# Out:
# year  Name
# 2006  3S        1
#       3SOFT     1
#       AD모터스     1
#       AJS       1
#       AK홀딩스     1
#                ..
# 2017  흥구석유      1
#       흥국        1
#       흥국에프엔비    1
#       흥아해운      1
#       희림        1
# Name: Code, Length: 19768, dtype: int64

# %%
df.groupby(['year', 'Name'])['Code'].nunique().nunique()
# Out:
# 1

# %% [markdown]
# # yearly returns

# %%
df[df['Name'] == '동화약품']
# Out:
#           Code  Name  결산월             시가총액           유통시가총액     PER   PBR  \
# 0      A000020  동화약품   12 113122453500.000  65520525067.000  11.230 0.550
# 2007 2953.000 16272.000 3100.000      NaN 4470.000 48550.000 530.000
# 2008 2379.000   890.000 1526.000      NaN 1530.000 33000.000 380.000
# 2009 5246.000   365.000 2070.000      NaN 2485.000 31400.000 685.000
# 2010  906.000       NaN 1788.000 8280.000 2350.000 50000.000 685.000
#
# Name        금호산업      금호석유  금호에이치티      금호전기     금호타이어    금화피에스시  기가레인  \
# year
# 2006  694596.000 33000.000     NaN 37541.000 37622.000  4070.000   NaN
# 2007 1622660.000 59500.000     NaN 31730.000 41802.000  7830.000   NaN
# 2008  369828.000 18300.000     NaN 22608.000 13406.000  6490.000   NaN
# 2009  238812.000 20650.000     NaN 55231.000 10764.000 13550.000   NaN
# 2010  120275.000 90400.000     NaN 40753.000 13850.000 12100.000   NaN
#
# Name       기린    기산텔레콤     기신정기       기아차    까뮤이앤씨    깨끗한나라  나노     나노메딕스  \
# year
# 2006 1370.000 7300.000      NaN 13450.000  715.000 3983.000 NaN 11851.000
# 2007  980.000 4065.000      NaN 10100.000 1170.000 5716.000 NaN  4286.000
# 2008  930.000 2005.000 3500.000  6550.000  589.000 2454.000 NaN  1810.000
# 2009   40.000 2120.000 4250.000 20050.000  700.000 4575.000 NaN  2086.000
# 2010      NaN 3760.000 5990.000 50600.000  580.000 4477.000 NaN  1742.000
#
# Name  나노스  나노신소재     나노엔텍     나노캠텍   나노트로닉스    나노하이텍    나라엠앤디    나리지*온  나무가  \
# year
# 2006  NaN    NaN 3005.000      NaN 5670.000 2335.000 2250.000 2050.000  NaN
# 2007  NaN    NaN 2630.000 5296.000 8150.000 1040.000 2350.000 2150.000  NaN
# 2008  NaN    NaN 2225.000 2254.000 4245.000  260.000 2030.000 1355.000  NaN
# 2009  NaN    NaN 5150.000 5134.000 9600.000   10.000 3000.000 3465.000  NaN
# 2010  NaN    NaN 4995.000 5274.000 3920.000      NaN 3060.000 5400.000  NaN
#
# Name  나스미디어  나이벡  나이스디앤비     나이스메탈  나이스정보통신          남광토건   남선알미늄       남성  \
# year
# 2006    NaN  NaN     NaN 20123.000 4065.000  53057964.000 298.000  995.000
# 2007    NaN  NaN     NaN  7943.000 4285.000 125040128.000 915.000 1045.000
# 2008    NaN  NaN     NaN  2668.000 2440.000 153274992.000 373.000  700.000
# 2009    NaN  NaN     NaN   898.000 3640.000  91080928.000 817.000  880.000
# 2010    NaN  NaN     NaN   309.000 4205.000  38876008.000 992.000  820.000
#
# Name       남양유업    남영비비안    남한제지      남해화학  남화토건  내츄럴엔도텍     네스테크  네오디안테크놀로지  \
# year
# 2006 839000.000 2725.000 417.000  2935.000   NaN     NaN  700.000        NaN
# 2007 900000.000 4209.000 435.000 14600.000   NaN     NaN 1620.000        NaN
# 2008 470500.000 2599.000 100.000 18400.000   NaN     NaN  585.000   1007.000
# 2009 554000.000 3001.000   5.000 18650.000   NaN     NaN  690.000   3216.000
# 2010 695000.000 3899.000     NaN 17700.000   NaN     NaN  499.000    832.000
#
# Name    네오리소스    네오세미테크  네오오토      네오위즈   네오위즈홀딩스     네오티스      네오팜     네오퍼플  \
# year
# 2006  820.000       NaN   NaN       NaN 34900.000      NaN      NaN 1264.000
# 2007 1465.000  6797.000   NaN       NaN 11650.000      NaN 9032.000 1970.000
# 2008   95.000  3204.000   NaN  9925.000  3700.000 2965.000 3400.000  806.000
# 2009  110.000 13100.000   NaN 40550.000 16600.000 4245.000 7300.000 1151.000
# 2010      NaN   150.000   NaN 45950.000 13600.000 4300.000 5150.000  400.000
#
# Name  네이블     네이처셀   네이쳐글로벌       네패스   네패스신소재   네프로아이티       넥센    넥센타이어  \
# year
# 2006  NaN 2018.000      NaN  8361.000      NaN      NaN 2070.000 1760.000
# 2007  NaN 1961.000 5750.000  7114.000      NaN      NaN 3095.000 4045.000
# 2008  NaN  896.000 1235.000  2371.000 2890.000      NaN 1485.000 2030.000
# 2009  NaN  645.000  615.000 13873.000 5380.000      NaN 5390.000 6760.000
# 2010  NaN  527.000    5.000 16450.000 3400.000 2020.000 6300.000 8400.000
#
# Name    넥센테크  넥솔론      넥스지      넥스턴    넥스트BT  넥스트리밍  넥스트바이오홀딩스  넥스트아이  \
# year
# 2006 414.000  NaN      NaN      NaN 3806.000    NaN   3645.000    NaN
# 2007 368.000  NaN      NaN 7346.000 3911.000    NaN   6140.000    NaN
# 2008 174.000  NaN 2170.000 1138.000 1512.000    NaN   2375.000    NaN
# 2009 659.000  NaN 4350.000 2718.000  949.000    NaN   3130.000    NaN
# 2010 598.000  NaN 3800.000 3359.000 1720.000    NaN   1870.000    NaN
#
# Name     넥스트칩     넥슨지티  넵튠    노루페인트     노루홀딩스        녹십자  녹십자랩셀      녹십자셀  \
# year
# 2006      NaN 8039.000 NaN      NaN  6224.000  54398.000    NaN 17758.000
# 2007      NaN 7963.000 NaN 4380.000 11700.000  85746.000    NaN 25114.000
# 2008 1414.000 3750.000 NaN 2380.000  4890.000  86115.000    NaN  7493.000
# 2009 3996.000 5250.000 NaN 3155.000  5900.000 116173.000    NaN 10818.000
# 2010 8222.000 7750.000 NaN 3305.000  5950.000 130431.000    NaN  7789.000
#
# Name  녹십자엠에스    녹십자홀딩스    녹원씨엔아이         농심     농심홀딩스     농우바이오    누리텔레콤  \
# year
# 2006     NaN  5950.000 11482.000 285000.000 89000.000  4500.000 4400.000
# 2007     NaN  8682.000 16534.000 194500.000 77000.000  6800.000 7300.000
# 2008     NaN  5729.000  9450.000 244500.000 58000.000  4590.000 3830.000
# 2009     NaN  8093.000  8039.000 249000.000 71200.000  9290.000 9490.000
# 2010     NaN 10714.000 10178.000 203500.000 58100.000 10950.000 6450.000
#
# Name  누리플랜  뉴로스      뉴보텍      뉴인텍   뉴젠비아이티     뉴젠아이씨티    뉴켐진스템셀  뉴트리바이오텍  \
# year
# 2006   NaN  NaN 1742.000 7160.000 6232.000 165794.000 29581.000      NaN
# 2007   NaN  NaN 1190.000 3949.000 2730.000  53438.000 13205.000      NaN
# 2008   NaN  NaN  880.000 2682.000  280.000  16856.000  1135.000      NaN
# 2009   NaN  NaN  775.000 6886.000   20.000   3037.000   110.000      NaN
# 2009 18306.000 137000.000 48707.000 1828796.000  65100.000 1120.000  846.000
# 2010 25760.000 181000.000 61749.000 1259723.000  88500.000 1090.000 2790.000
#
# Name    대호피앤씨     대화제약  더블유게임즈   더블유에프엠     더존디지털     더존비즈온      더체인지  덕산네오룩스  \
# year
# 2006 1249.000 5900.000     NaN 5440.000 21500.000 25224.000 24717.000     NaN
# 2007 1815.000 4250.000     NaN 9433.000 15350.000 13875.000 34136.000     NaN
# 2008  588.000 1885.000     NaN 3674.000  6840.000  4491.000  1980.000     NaN
# 2009  869.000 2770.000     NaN 4380.000  6800.000 11900.000  1145.000     NaN
# 2010 1525.000 2590.000     NaN 3144.000       NaN 16750.000   462.000     NaN
#
# Name    덕산하이메탈       덕성  덕신하우징     덕양산업  데브시스터즈  데일리블록체인       데코     데코앤이  \
# year
# 2006  5217.000 3680.000    NaN  836.000     NaN      NaN 1835.000 2842.000
# 2007  4407.000 3050.000    NaN 1005.000     NaN      NaN 1170.000 1261.000
# 2008  1445.000 1330.000    NaN  625.000     NaN      NaN  470.000  450.000
# 2009 12289.000 2450.000    NaN  717.000     NaN      NaN  395.000  721.000
# 2010 19116.000 2570.000    NaN 1050.000     NaN      NaN  585.000  946.000
#
# Name  덱스터  덴티움    도레이케미칼         도움    도이치모터스  도화엔지니어링    동국S&C     동국산업  \
# year
# 2006  NaN  NaN  7300.000 105751.000 11646.000      NaN      NaN 1339.000
# 2007  NaN  NaN  7720.000  51500.000 12051.000      NaN      NaN 5750.000
# 2008  NaN  NaN  6010.000   1900.000  5823.000      NaN      NaN 4800.000
# 2009  NaN  NaN 11450.000        NaN  2155.000      NaN      NaN 4655.000
# 2010  NaN  NaN 12050.000        NaN  4300.000      NaN 7690.000 5040.000
#
# Name     동국실업   동국알앤에스      동국제강     동국제약      동남합성       동방     동방선기  \
# year
# 2006  582.000 1516.000 21226.000      NaN  5516.000 3367.000      NaN
# 2007 2219.000 3049.000 42950.000      NaN 10487.000 6311.000      NaN
# 2008  708.000 1520.000 24297.000 2243.000  7774.000 1935.000      NaN
# 2009  966.000 2030.000 24388.000 2920.000  5480.000 2203.000      NaN
# 2010 1818.000 1930.000 31704.000 2890.000  6190.000 1939.000 2290.000
#
# Name    동방아그로    동부CNI       동부건설  동부일렉트로닉스        동부제철     동산진흥        동서  \
# year
# 2006 3930.000 2430.000 364964.000  2155.000  633429.000 3470.000  6863.000
# 2007 6710.000 5230.000 502487.000  1960.000 1076830.000 8410.000  7328.000
# 2008 6370.000 1750.000 117846.000       NaN  501817.000  565.000  7613.000
# 2009 6430.000 2995.000 178991.000       NaN  992746.000  220.000  9831.000
# 2010 6390.000 6100.000 169893.000       NaN  842356.000      NaN 11359.000
#
# Name     동성제약  동성코퍼레이션    동성하이켐     동성화인텍     동성화학      동신건설      동신제약  \
# year
# 2006 1732.000      NaN 3148.000 13199.000 2211.000  2655.000 25250.000
# 2007 2130.000      NaN 3583.000 11572.000 3369.000 11800.000       NaN
# 2007   NaN   NaN 29900.000 108720.000 NaN  948.000 18191.000     NaN
# 2008   NaN   NaN 14550.000  54274.000 NaN 1080.000 22335.000     NaN
# 2009   NaN   NaN 16350.000  69978.000 NaN 1060.000 15850.000     NaN
# 2010   NaN   NaN 28000.000  74033.000 NaN 1472.000 12350.000     NaN
#
# Name       디보스     디비케이   디스플레이텍      디씨씨       디씨엠      디아이     디아이디  \
# year
# 2006 65967.000 3926.000 1488.000 2305.000  3945.000 2440.000 2130.000
# 2007 67467.000 3239.000 2018.000 2800.000  8900.000 2345.000 1400.000
# 2008  1762.000 1890.000  561.000 3155.000  5280.000  955.000  780.000
# 2009    90.000 2360.000 3461.000      NaN  7990.000 1305.000 1625.000
# 2010       NaN 2045.000 4600.000      NaN 11900.000 1895.000 5170.000
#
# Name     디아이씨  디알텍      디앤샵      디에스    디에스케이      디에스티   디에스티로봇    디에스피  \
# year
# 2006      NaN  NaN      NaN 6570.000      NaN 27727.000      NaN 839.000
# 2007      NaN  NaN 6450.000 5900.000      NaN 11618.000 1411.000 580.000
# 2008 1726.000  NaN 2100.000 2400.000      NaN  3432.000  357.000  60.000
# 2009 2802.000  NaN 2005.000 4875.000      NaN  2294.000  564.000     NaN
# 2010 5604.000  NaN 1910.000 3840.000 2072.000  3296.000 1226.000     NaN
#
# Name    디에이치패션  디에이치피코리아  디에이테크놀로지     디에이피  디엔에이링크     디엔에프      디엠씨  디엠티  \
# year
# 2006 16472.000       NaN       NaN 1300.000     NaN      NaN      NaN  NaN
# 2007  8173.000       NaN       NaN  900.000     NaN      NaN      NaN  NaN
# 2008  2115.000       NaN       NaN  480.000     NaN 1735.000      NaN  NaN
# 2009  1308.000       NaN       NaN 2025.000     NaN 2052.000      NaN  NaN
# 2010   500.000       NaN       NaN 2260.000     NaN 3630.000 4844.000  NaN
#
# Name        디오       디와이  디와이파워     디이엔티  디젠스     디지아이  디지탈옵틱    디지털대성  \
# year
# 2006  6910.000  3677.000    NaN 2370.000  NaN 5250.000    NaN 4368.000
# 2007 12250.000  6750.000    NaN 1975.000  NaN 3690.000    NaN 3945.000
# 2008  5220.000  2590.000    NaN 1045.000  NaN 1650.000    NaN 1305.000
# 2009  8300.000  4375.000    NaN 1835.000  NaN 3165.000    NaN 2345.000
# 2010  8780.000 10850.000    NaN 4055.000  NaN 3240.000    NaN 2010.000
#
# Name    디지텍시스템    디지틀조선  디케이디앤아이  디케이락  디티알오토모티브  디티앤씨       디패션      디피씨  딜리  \
# year
# 2006       NaN 2040.000 2478.000   NaN  8903.000   NaN 27030.000 1640.000 NaN
# 2007       NaN 2985.000 5490.000   NaN 13679.000   NaN  9515.000 1725.000 NaN
# 2008 11650.000 1950.000 1540.000   NaN 12141.000   NaN  3030.000  730.000 NaN
# 2009 25000.000 2420.000 1500.000   NaN 13371.000   NaN  6182.000 1435.000 NaN
# 2010 21300.000 2950.000 2045.000   NaN 15217.000   NaN   950.000 1380.000 NaN
#
# Name     라온시큐어   라이브플렉스  라이온켐텍     라이트론       락앤락  램테크놀러지  랩지노믹스  레고켐바이오  \
# 2010 1579.000 787.000  7010.000      NaN 1676.000      NaN 1125.000 9366.000
#
# Name  만도      만호제강     매일홀딩스  매직마이크로      매커스  맥스로텍       맥스브로      멀티캠퍼스  \
# year
# 2006 NaN  9630.000 12731.000     NaN      NaN   NaN        NaN        NaN
# 2007 NaN 13850.000 10972.000     NaN 1530.000   NaN 161662.000 130800.000
# 2008 NaN 10900.000  4953.000     NaN 1040.000   NaN  13218.000  52700.000
# 2009 NaN 15400.000  8594.000     NaN  980.000   NaN  13190.000  57300.000
# 2010 NaN 16950.000  8099.000     NaN 1300.000   NaN    470.000  66100.000
#
# Name     메가스터디  메가스터디교육  메가엠디  메디아나      메디톡스     메디포스트     메디프론      메디플란트  \
# year
# 2006 23167.000      NaN   NaN   NaN       NaN  8482.000 3520.000 126468.000
# 2007 45389.000      NaN   NaN   NaN       NaN  7215.000 2864.000 173109.000
# 2008 30709.000      NaN   NaN   NaN       NaN  5509.000 1398.000  54713.000
# 2009 40327.000      NaN   NaN   NaN 20299.000  8092.000 4758.000  16151.000
# 2010 29730.000      NaN   NaN   NaN 25950.000 21280.000 4248.000   9314.000
#
# Name  메지온     메카포럼  메타바이오메드  멕아이씨에스       멜파스     명문제약     모나리자      모나미  모다  \
# year
# 2006  NaN 1890.000      NaN     NaN       NaN      NaN 1300.000 1951.000 NaN
# 2007  NaN 3190.000      NaN     NaN       NaN      NaN  995.000 2219.000 NaN
# 2008  NaN  210.000 1445.000     NaN       NaN      NaN  345.000 1110.000 NaN
# 2009  NaN  255.000 2381.000     NaN       NaN 2124.000  730.000 1706.000 NaN
# 2010  NaN    5.000 2015.000     NaN 29000.000 1974.000  740.000 1533.000 NaN
#
# Name    모다이노칩     모델라인      모두투어    모라리소스      모린스  모바일리더  모바일어플라이언스     모베이스  \
# year
# 2006 4160.000 4400.000 11793.000 2522.000      NaN    NaN        NaN      NaN
# 2007 1699.000 1800.000 23542.000 2673.000      NaN    NaN        NaN      NaN
# 2008 2250.000      NaN  4583.000  816.000      NaN    NaN        NaN      NaN
# 2009 2925.000      NaN 12416.000 1130.000      NaN    NaN        NaN      NaN
# 2010 2422.000      NaN 15798.000  150.000 7990.000    NaN        NaN 1907.000
#
# Name  모비스     모빌링크      모빌탑      모아텍        모젬      모토닉      모헨즈    무림P&P  \
# year
# 2006  NaN 3525.000 3647.000 2949.000 17350.000 4695.000 1063.000 1192.000
# 2007  NaN 3045.000 2499.000 6783.000  4300.000 8690.000  897.000 5125.000
# 2008  NaN  595.000  330.000 4367.000   750.000 5970.000 3589.000 2660.000
# 2009  NaN   10.000    5.000 7690.000   750.000 8490.000 2530.000 2750.000
# 2010  NaN      NaN      NaN 7230.000       NaN 8600.000 3520.000 6225.000
#
# Name     무림SP    무림페이퍼       무학     문배철강  미동앤씨네마     미디어코프     미래SCI  \
# year
# 2006 2640.000 5075.000 4698.000 1295.000     NaN 30716.000 17190.000
# ...
# year
# 2006  5610.000      NaN  NaN 4940.000 14209.000    NaN   NaN 4000.000
# 2007 12300.000      NaN  NaN 3590.000 15940.000    NaN   NaN 3800.000
# 2008  4320.000      NaN  NaN  940.000 11589.000    NaN   NaN 3185.000
# 2009 11550.000      NaN  NaN  500.000 12432.000    NaN   NaN 4205.000
# 2010 14400.000      NaN  NaN   30.000 13987.000    NaN   NaN 4320.000
#
# Name      하이트맥주     하이트진로  하이트진로홀딩스       하츠     한국가구    한국가스공사   한국경제TV  \
# year
# 2006        NaN       NaN 63869.000 3340.000 1035.000 39826.000 3725.000
# 2007        NaN       NaN 76161.000 3800.000 1360.000 62640.000 3490.000
# 2008        NaN       NaN 16400.000 1435.000 1195.000 55583.000 1380.000
# 2009 170000.000       NaN 28900.000 2085.000 1165.000 46980.000 3730.000
# 2010 120500.000 35400.000 20200.000 2905.000 1200.000 46883.000 2915.000
#
# Name      한국공항   한국기술산업    한국기업평가     한국내화      한국단자  한국맥널티       한국석유  \
# year
# 2006 31950.000  645.000 17700.000 1925.000 17850.000    NaN  20200.000
# 2007 53000.000 3060.000 34950.000 5210.000 24000.000    NaN 129000.000
# 2008 26750.000 2140.000 23050.000 1900.000 10950.000    NaN  67600.000
# 2009 32500.000 1730.000 17000.000 3450.000 18350.000    NaN  50600.000
# 2010 45650.000      NaN 18600.000 3410.000 19950.000    NaN  51100.000
#
# Name     한국선재      한국쉘석유     한국알콜      한국유리      한국전력   한국전자금융  한국전자인증  \
# year
# 2006 1841.000  62000.000 2800.000 39650.000 42400.000      NaN     NaN
# 2007 2264.000  81900.000 3191.000 34650.000 39650.000 6900.000     NaN
# 2008 4580.000  70300.000 4600.000 20050.000 29600.000 2565.000     NaN
# 2009 2350.000 120500.000 4655.000 21550.000 34100.000 2790.000     NaN
# 2010 2575.000 224000.000 4305.000 30950.000 30200.000 2990.000     NaN
#
# Name  한국전자홀딩스    한국정밀기계   한국정보공학  한국정보인증   한국정보통신      한국제지  한국종합기술     한국주강  \
# year
# 2006 1400.000       NaN 3000.000     NaN 3165.000 33100.000     NaN 2519.000
# 2007 1684.000       NaN 3800.000     NaN 2190.000 36400.000     NaN 5029.000
# 2008  552.000       NaN 1825.000     NaN  985.000 30400.000     NaN 2442.000
# 2009 1439.000       NaN 2400.000     NaN 1400.000 37000.000     NaN 4755.000
# 2010 1309.000 43307.000 3695.000     NaN 4100.000 26000.000     NaN 4460.000
#
# Name    한국주철관     한국철강     한국카본    한국컴퓨터  한국코퍼레이션  한국콜마  한국콜마홀딩스     한국큐빅  \
# year
# 2006 3900.000      NaN 7420.000 3750.000 3809.000   NaN 2077.000 2567.000
# 2007 5070.000      NaN 6890.000 1970.000 6777.000   NaN 1966.000 4227.000
# 2008 2400.000      NaN 4800.000 1620.000 2067.000   NaN 1237.000 1477.000
# 2009 4610.000 8820.000 7300.000 2365.000 2372.000   NaN 1868.000 1727.000
# 2010 3735.000 5660.000 5750.000 4085.000 1580.000   NaN 4254.000 1718.000
#
# Name  한국타이어  한국타이어월드와이드   한국테크놀로지   한국특수형강    한국팩키지    한국프랜지     한국합섬  한국항공우주  \
# year
# 2006    NaN    7824.000  6850.000 3285.000  621.000 2240.000 2840.000     NaN
# 2007    NaN    8863.000 17423.000 5300.000  780.000 2990.000  130.000     NaN
# 2008    NaN    7576.000  1274.000 5340.000  380.000 1302.000      NaN     NaN
# 2009    NaN   12627.000  2203.000 5690.000  800.000 2120.000      NaN     NaN
# 2010    NaN   15722.000  3811.000 4960.000 1100.000 2990.000      NaN     NaN
#
# Name  한국화장품  한국화장품제조   한글과컴퓨터      한네트     한농화성   한도하이테크        한독        한라  \
# year
# 2006    NaN 4119.000 8710.000 2875.000 1576.000 7360.000 15482.000 17221.000
# 2007    NaN 4442.000 5250.000 2620.000 1797.000 8960.000 19736.000 21452.000
# 2008    NaN 3384.000 2395.000 1735.000 1640.000   75.000 11278.000  6476.000
# 2009    NaN 3529.000 5110.000 2500.000 3740.000      NaN 12860.000 21489.000
# 2010    NaN 6620.000 5280.000 2725.000 3740.000      NaN 16323.000 19650.000
#
# Name    한라IMS  한라홀딩스     한미글로벌    한미반도체    한미사이언스  한미약품      한빛방송    한빛소프트  \
# year
# 2006      NaN    NaN       NaN 2590.000 11591.000   NaN 37200.000 9400.000
# 2007      NaN    NaN       NaN 3580.000 14390.000   NaN 28700.000 7930.000
# 2008 3898.000    NaN       NaN 1160.000  9841.000   NaN 22800.000 3400.000
# 2009 6570.000    NaN       NaN 2688.000 12127.000   NaN 22900.000 3830.000
# 2010 6840.000    NaN 13650.000 3256.000  5382.000   NaN 20750.000 3540.000
#
# Name        한샘     한서제약        한섬      한성기업     한세실업  한세엠케이  한세예스24홀딩스  \
# year
# 2006  7710.000 2230.000 17635.000  5320.000      NaN    NaN   3110.000
# 2007  6700.000 1675.000 12100.000  6210.000      NaN    NaN   4965.000
# 2008  6700.000 1285.000  7850.000  3385.000      NaN    NaN   2104.000
# 2009 11600.000 3440.000 16100.000 13100.000 5314.000    NaN   2779.000
# 2010 13850.000      NaN 18300.000 12900.000 4999.000    NaN   2493.000
#
# Name    한솔PNS  한솔로지스틱스  한솔시큐어     한솔신텍  한솔씨앤피   한솔아트원제지   한솔인티큐브  한솔제지  \
# year
# 2006 1963.000 3562.000    NaN      NaN    NaN 10271.000 1760.000   NaN
# 2007 1390.000 1844.000    NaN      NaN    NaN  6429.000 2300.000   NaN
# 2008 1298.000  695.000    NaN      NaN    NaN  3720.000 1155.000   NaN
# 2009 1765.000 1246.000    NaN      NaN    NaN  6457.000 1115.000   NaN
# 2010 1326.000 1827.000    NaN 3048.000    NaN  3981.000 1205.000   NaN
#
# Name     한솔케미칼    한솔테크닉스     한솔홀딩스    한솔홈데코  한스바이오메드      한신공영     한신기계  \
# year
# 2006  7900.000 33931.000  9084.000 1020.000      NaN 19100.000  760.000
# 2007  9340.000 25923.000 10849.000 1560.000      NaN 28400.000 1330.000
# 2008  5200.000  8822.000  6612.000  729.000      NaN 13650.000 1100.000
# 2009 12400.000 20562.000  7062.000 1040.000      NaN 18750.000 1240.000
# 2010 15750.000 45283.000  6805.000 1239.000 3295.000 10200.000 1750.000
#
# Name    한양디지텍    한양이엔지    한온시스템  한올바이오파마    한와이어리스   한익스프레스   한일네트웍스     한일단조  \
# year
# 2006 3530.000 4189.000 2470.000 2105.000 17972.000 1060.000 3473.000 1656.000
# 2007 3390.000 4777.000 1736.000 4320.000  6283.000 1285.000 3780.000 2008.000
# 2008 3725.000 3184.000 1450.000 2285.000  4019.000  625.000 1105.000 1350.000
# 2009 4710.000 6957.000 2690.000 4420.000  1155.000 1390.000 1525.000 2288.000
# 2010 4610.000 5650.000 4000.000 7360.000   396.000 2240.000 1545.000 4698.000
#
# Name     한일사료     한일시멘트      한일약품  한일진공     한일철강      한일화학     한전KPS  \
# year
# 2006  839.000 51799.000 12000.000   NaN 2145.000  9940.000       NaN
# 2007 1482.000 68123.000       NaN   NaN 2810.000 14000.000       NaN
# 2008 1072.000 41125.000       NaN   NaN  772.000  7770.000 25000.000
# 2009 1254.000 50480.000       NaN   NaN 1245.000  9100.000 42600.000
# 2010  951.000 37672.000       NaN   NaN 1660.000  8800.000 52400.000
#
# Name      한전기술  한전산업        한진      한진중공업  한진중공업홀딩스  한진칼     한진피앤씨      한진해운  \
# year
# 2006       NaN   NaN 30949.000        NaN 18218.000  NaN  9751.000       NaN
# 2007       NaN   NaN 37615.000        NaN 41900.000  NaN 24330.000       NaN
# 2008       NaN   NaN 34567.000 264941.000 11850.000  NaN 12475.000       NaN
# 2009       NaN   NaN 37996.000 209822.000 11500.000  NaN 13396.000       NaN
# 2010 90500.000   NaN 32568.000 353436.000 14950.000  NaN 19164.000 35725.000
#
# Name      한창     한창산업     한창제지     한컴MDS    한컴시큐어    한컴지엠디       한탑       한텔  \
# year
# 2006 697.000 4455.000 3301.000       NaN 3780.000 5263.000 1915.000 1310.000
# 2007 732.000 5000.000 2713.000 10600.000 2130.000 7431.000 1930.000  490.000
# 2008 278.000 3260.000  784.000  2390.000 1220.000 2085.000 1015.000   30.000
# 2009 344.000 3950.000  625.000  8700.000 1565.000 2450.000 1525.000      NaN
# 2010 302.000 3195.000  575.000  8140.000 1430.000 3745.000 2455.000      NaN
#
# Name       한프        한화  한화갤러리아타임월드     한화케미칼      한화테크윈   한화화인케미칼   해덕파워웨이  \
# year
# 2006 6900.000 34047.000   18200.000 11038.000  36289.000  7859.000      NaN
# 2007 3605.000 68872.000   14600.000 16536.000  45054.000 61187.000      NaN
# 2008 1537.000 18726.000   10550.000  6000.000  30463.000 25443.000      NaN
# 2009 4099.000 46498.000   13500.000 13500.000  90800.000 49126.000      NaN
# 2010 4682.000 45428.000   20250.000 31000.000 103500.000 47898.000 1838.000
#
# Name  해마로푸드서비스  해성디에스      해성산업  해성옵틱스    해원에스티  해태제과식품  핸즈코퍼레이션     행남자기  \
# year
# 2006       NaN    NaN  4680.000    NaN  800.000     NaN      NaN 4072.000
# 2007       NaN    NaN  7720.000    NaN 1500.000     NaN      NaN 4918.000
# 2008       NaN    NaN  5450.000    NaN  800.000     NaN      NaN 2116.000
# 2009    NaN    NaN 4535.000  99049.000  675.000      NaN 3525.000   NaN
# 2010    NaN    NaN 4115.000  71475.000  552.000 1952.000 5540.000   NaN
#
# Name      호텔신라   홈센타홀딩스     홈캐스트     화성밸브      화성산업   화승알앤에이  화승엔터프라이즈  \
# year
# 2006 15150.000  493.000 2615.000 1504.000 16500.000 1250.000       NaN
# 2007 22500.000 1678.000 2700.000 1771.000 15000.000 1190.000       NaN
# 2008 12850.000 2416.000 1745.000 1223.000  5300.000  518.000       NaN
# 2009 20600.000 2305.000 3455.000 2041.000  5170.000  803.000       NaN
# 2010 27750.000 1105.000 2695.000 2844.000  4315.000 2835.000       NaN
#
# Name    화승인더        화신  화신정공     화신테크  화이브라더스코리아  화인베스틸      화일약품  화진  \
# year
# 2006 661.000  2430.000   NaN      NaN        NaN    NaN  7260.000 NaN
# 2007 640.000  2995.000   NaN 1935.000        NaN    NaN 13250.000 NaN
# 2008 410.000  1335.000   NaN  595.000        NaN    NaN  3240.000 NaN
# 2009 959.000  3845.000   NaN 1530.000        NaN    NaN  4535.000 NaN
# 2010 894.000 11500.000   NaN 2090.000        NaN    NaN  3750.000 NaN
#
# Name     화천기계      화천기공     환인제약    황금에스티        효성    효성ITX    효성오앤비  \
# year
# 2006 1450.000 26700.000 8900.000 6133.000 16185.000      NaN      NaN
# 2007 1835.000 53800.000 7675.000 8403.000 34619.000      NaN      NaN
# 2008 1115.000 22000.000 5750.000 2663.000 22606.000 2820.000 2268.000
# 2009 1350.000 34100.000 6550.000 6572.000 50420.000 4200.000 2960.000
# 2010 2100.000 39500.000 6940.000 6425.000 62729.000 5450.000 3878.000
#
# Name       후성         훈영    휘닉스소재     휘튼  휠라코리아      휴니드      휴리프       휴맥스  \
# year
# 2006      NaN 294147.000 3246.000 45.000    NaN 9900.000 7095.000       NaN
# 2007 4793.000 131316.000 1669.000    NaN    NaN 8920.000 2440.000       NaN
# 2008 2908.000  11500.000  398.000    NaN    NaN 2870.000  360.000       NaN
# 2009 3750.000  22700.000 2100.000    NaN    NaN 7160.000   10.000       NaN
# 2010 3711.000   4540.000 1180.000    NaN    NaN 5970.000      NaN 16950.000
#
# Name    휴맥스홀딩스   휴먼텍코리아  휴메딕스  휴비스      휴비츠       휴스틸  휴온스   휴온스글로벌  휴젤  \
# year
# 2006 23492.000 2298.000   NaN  NaN 3330.000 15800.000  NaN      NaN NaN
# 2007 13192.000 3103.000   NaN  NaN 2815.000 18000.000  NaN 6385.000 NaN
# 2008  7264.000 2956.000   NaN  NaN 1730.000 14600.000  NaN 4538.000 NaN
# 2009 14200.000 1807.000   NaN  NaN 4270.000 16000.000  NaN 5549.000 NaN
# 2010  7620.000 1275.000   NaN  NaN 4850.000 17450.000  NaN 4206.000 NaN
#
# Name       휴켐스     흥구석유       흥국  흥국에프엔비     흥아해운        희림    희훈디앤지
# year
# 2006  5356.000 1976.000      NaN     NaN 1979.000  2941.000 1212.000
# 2007 11430.000 3393.000      NaN     NaN 3011.000  8072.000 1120.000
# 2008 13179.000 2420.000      NaN     NaN 1053.000  7687.000  210.000
# 2009 18336.000 2660.000      NaN     NaN 1151.000 11000.000    5.000
# 2010 19600.000 2320.000 2190.000     NaN 1935.000  8320.000      NaN

# %% [markdown]
# - rtn 구하기
#     - $p_{n+1}\over{p_{n}}$ - 1

# %%
# 1. year_price_df.pct_change() == year_price_df / year_price_df.shift() - 1
# 2. `shift(-1)`을 하는 이유? 
#    - 데이터를 "xx년도에서 1년동안 들고있었더니, xx만큼 수익이 났다"로 해석하고 싶기 때문
yearly_rtn_df = yearly_price_df.pct_change(fill_method=None).shift(-1)
yearly_rtn_df.head()

# %% [markdown]
# - 상장폐지 종목은 어떻게 처리가 되나?

# %%
yearly_price_df['AD모터스']

# %%
yearly_price_df['AD모터스'].pct_change(fill_method=None).shift(-1)

# %% [markdown]
# - 2011/12에 매수했으면, 1년의 rtn value는은 보장됨.
# - 2012/12에 매수했으면,
#     - 2013년 1월에 상장폐지 되었을 수도 있고, 2013년 12월(초)에 되었을 수도 있기 때문에 => rtn이 nan처리됨

# %% [markdown]
# # Single Indicator(지표) backtesting

# %% [markdown]
# - Section1: `reset_index()`
# - Section2: boolean selection, DataFrame arithmetic operation, dtype변환
# - Section3: `groupby()` & `aggregation`
# - Section4: `join()`, `pivot()`
# - Section5: visualization

# %% [markdown]
# ## DataFrame(matrix) Multiplication 복습

# %%
a = pd.DataFrame([[1,2], [3, np.nan,], [5,6]], columns=["a", "b"])
b = pd.DataFrame([[1,2], [3, 4,], [5,6]], columns=["a", "b"])*10
a
b
# Out:
#    a     b
# 0  1 2.000
# 1  3   NaN
# 2  5 6.000
#     a   b
# 0  10  20
# 1  30  40
# 2  50  60

# %%
a * b
# Out:
#      a       b
# 0   10  40.000
# 1   90     NaN
# 2  250 360.000

# %%
a = pd.DataFrame([[1,2], [3, np.nan,], [5,6]], columns=["a", "b"])
b = pd.DataFrame([[1,2,3], [3, 4,5], [5,6,7]], columns=["c", "b", "d"])*10
a
b
# Out:
#    a     b
# 0  1 2.000
# 1  3   NaN
# 2  5 6.000
#     c   b   d
# 0  10  20  30
# 1  30  40  50
# 2  50  60  70

# %%
a * b
# Out:
#     a       b   c   d
# 0 NaN  40.000 NaN NaN
# 1 NaN     NaN NaN NaN
# 2 NaN 360.000 NaN NaN

# %%
return_df = pd.DataFrame(
    [
        [np.nan,  np.nan, 2     ],
        [3,       np.nan, 3     ],
        [5,       6,      np.nan], 
    ],
    columns=["삼성", "현대", "SK"]
)
asset_on_df = pd.DataFrame(
    [
        [0, 1],
        [0, 1],
        [1, 0], 
    ],
    columns=["삼성", "SK"]
)
return_df
asset_on_df
# Out:
#      삼성    현대    SK
# 0   NaN   NaN 2.000
# 1 3.000   NaN 3.000
# 2 5.000 6.000   NaN
#    삼성  SK
# 0   0   1
# 1   0   1
# 2   1   0

# %%
return_df * asset_on_df
# Out:
#      SK    삼성  현대
# 0 2.000   NaN NaN
# 1 3.000 0.000 NaN
# 2   NaN 5.000 NaN

# %%
(return_df * asset_on_df).mean(axis=1)
# Out:
# 0   2.000
# 1   1.500
# 2   5.000
# dtype: float64

# %%
# 해결책
asset_on_df = asset_on_df.replace(0, np.nan)

# %%
return_df * asset_on_df
# Out:
#      SK    삼성  현대
# 0 2.000   NaN NaN
# 1 3.000   NaN NaN
# 2   NaN 5.000 NaN

# %%
# "동일가중" 방식의 투자인 경우, 포트폴리오 평균수익률 구하는 방법
(return_df * asset_on_df).mean(axis=1)
# Out:
# 0   2.000
# 1   3.000
# 2   5.000
# dtype: float64

# %% [markdown]
# ## top_n

# %%
df.head()
# Out:
#       Code   Name  결산월              시가총액            유통시가총액     PER   PBR  \
# 0  A000020   동화약품   12  113122453500.000   65520525067.000  11.230 0.550
# 1  A000040  KR모터스   12  144125742600.000  111855988832.000  97.070 1.440
# 2  A000050     경방   12  275600000000.000  180269960000.000 426.230 0.860
# 3  A000070  삼양홀딩스   12  602432236800.000  281576827480.000   8.360 0.570
# 4  A000100   유한양행   12 1382097577000.000 1018467704491.000  25.280 2.670
#
#     PSR  P/FCF1(Adj., FY End)  EV/EBITDA  EV/EBIT      DPS  year   수정주가  \
# 0 0.560                 4.390      3.480    4.390  600.000  2006   6460
# 1 0.820                -7.780     16.840   40.670    0.000  2006   1098
# 2 2.010                 5.780     15.340   20.660    0.000  2006  10339
# 3 0.530                11.160      4.600    6.210 1050.000  2006  63563
# 4 4.070               -27.990     15.720   17.160 1000.000  2006  24911
#
#       ROA        비유동부채          자산총계
# 0   3.810 11961630.000 195293494.000
# 1 -21.980 28190608.000  81250312.000
# 2  -1.800 17344611.000 515345506.000
# 3   5.490 60878366.000 973804019.000
# 4   7.530 95212024.000 746417156.000

# %%
indicator = "ROA"

# %%
top_n = 10

# %%
top_n_indicator_df = df.groupby(['year'])[indicator].nlargest(top_n).reset_index()
top_n_indicator_df.head()
top_n_indicator_df.tail()
# Out:
#    year  level_1    ROA
# 0  2006     1079 64.490
# 1  2006     1442 62.610
# 2  2006     1455 58.550
# 3  2006     1402 51.440
# 4  2006     1467 48.400
#      year  level_1    ROA
# 115  2017    19658 52.050
# 116  2017    19696 48.980
# 117  2017    19730 46.440
# 118  2017    18265 41.830
# 119  2017    19729 39.480

# %%
# 종목 indexing
top_n_roa_df = df.loc[top_n_indicator_df['level_1']]
top_n_roa_df.head()
# Out:
#          Code      Name  결산월             시가총액           유통시가총액    PER   PBR  \
# 1079  A048870  시너지이노베이션   12 252240105600.000 186001853869.000  0.630 0.180
# 1442  A080000      에스엔유   12 177821980000.000 115242157510.000 11.850 3.280
# 1455  A082800    루미마이크로   12  59698800000.000  28249472160.000 36.020 2.220
# 1402  A075130      플랜티넷   12 127680000000.000 132685056000.000 27.240 5.140
# 1467  A084370      유진테크   12  31170176000.000  14724791142.000    NaN 0.000
#
#         PSR  P/FCF1(Adj., FY End)  EV/EBITDA  EV/EBIT      DPS  year   수정주가  \
# 1079  0.100                 0.560      7.730    9.240 1050.000  2006  45925
# 1442  3.440               -43.050      9.480   10.330   60.000  2006   4217
# 1455  2.730               -15.020     14.720   41.420    0.000  2006   1311
# 1402 10.070                51.340     21.080   26.370  110.000  2006  16200
# 1467    NaN                   NaN        NaN      NaN   65.000  2006   1447
#
#         ROA       비유동부채         자산총계
# 1079 64.490  484745.000 97283559.000
# 1442 62.610 4739832.000 31210115.000
# 1455 58.550 3674557.000 19836533.000
# 1402 51.440 1988671.000 26339925.000
# 1467 48.400 1324699.000 14297125.000

# %%
indicator_df = top_n_roa_df.pivot(index="year", columns="Name", values="ROA")
indicator_df.head()
# Out:
# Name    DMS  GKL    ISC  KG이니시스  MP한강  NAVER  S&K폴리텍     SY  골프존뉴딘   나노캠텍  \
# year
# 2006 45.300  NaN    NaN     NaN   NaN    NaN     NaN    NaN    NaN    NaN
# 2007    NaN  NaN    NaN  46.090   NaN    NaN     NaN 34.510    NaN 35.540
# 2008    NaN  NaN 47.170     NaN   NaN    NaN  36.670    NaN    NaN    NaN
# 2009    NaN  NaN    NaN     NaN   NaN 41.180     NaN    NaN    NaN    NaN
# 2010    NaN  NaN    NaN     NaN   NaN 40.050     NaN    NaN    NaN    NaN
#
# Name  나노트로닉스  내츄럴엔도텍  네이쳐글로벌  넥스트리밍  넥스트바이오홀딩스  넥스트아이   넥스트칩  다믈멀티미디어  더블유게임즈  \
# year
# 2006     NaN     NaN     NaN    NaN        NaN    NaN    NaN      NaN     NaN
# 2007     NaN     NaN  42.310    NaN     45.110    NaN    NaN      NaN     NaN
# 2008     NaN     NaN     NaN    NaN        NaN    NaN 39.530   39.340     NaN
# 2009  38.390     NaN     NaN    NaN     45.910    NaN    NaN      NaN     NaN
# 2010     NaN     NaN     NaN    NaN        NaN    NaN    NaN      NaN     NaN
#
# Name  동양  동양네트웍스   디엔에프  디지텍시스템  라이온켐텍  루미마이크로  메지온  모다    모린스  미동앤씨네마  보해양조  \
# year
# 2006 NaN     NaN    NaN     NaN    NaN  58.550  NaN NaN    NaN     NaN   NaN
# 2007 NaN     NaN    NaN     NaN    NaN     NaN  NaN NaN    NaN     NaN   NaN
# 2008 NaN     NaN 45.310  48.830    NaN     NaN  NaN NaN    NaN     NaN   NaN
# 2009 NaN     NaN    NaN     NaN    NaN     NaN  NaN NaN    NaN     NaN   NaN
# 2010 NaN     NaN    NaN     NaN    NaN     NaN  NaN NaN 53.790     NaN   NaN
#
# Name  부방    뷰웍스  비아트론  사파이어테크놀로지  삼성바이오로직스   서호전기  선데이토즈  성지건설  성창기업지주  \
# year
# 2006 NaN    NaN   NaN        NaN       NaN    NaN    NaN   NaN     NaN
# 2007 NaN    NaN   NaN        NaN       NaN    NaN    NaN   NaN     NaN
# 2008 NaN    NaN   NaN        NaN       NaN    NaN    NaN   NaN     NaN
# 2009 NaN 35.490   NaN        NaN       NaN    NaN    NaN   NaN     NaN
# 2010 NaN    NaN   NaN        NaN       NaN 41.980    NaN   NaN     NaN
#
# Name  셀트리온제약  슈프리마에이치큐  슈피겐코리아  시너지이노베이션  신세계  썸에이지    씨모텍  씨엘인터내셔널  씨젠  \
# year
# 2006     NaN       NaN     NaN    64.490  NaN   NaN    NaN      NaN NaN
# 2007  36.900       NaN     NaN       NaN  NaN   NaN    NaN   41.620 NaN
# 2008     NaN       NaN     NaN       NaN  NaN   NaN    NaN      NaN NaN
# 2009     NaN    36.270     NaN       NaN  NaN   NaN 39.120      NaN NaN
# 2010     NaN       NaN     NaN       NaN  NaN   NaN    NaN      NaN NaN
#
# Name  씨케이에이치  아나패스  아이디스홀딩스  아이디에스  아이즈비전  아트라스BX  앤디포스  에스디생명공학   에스엔유  \
# year
# 2006     NaN   NaN      NaN 43.560    NaN     NaN   NaN      NaN 62.610
# 2007     NaN   NaN      NaN    NaN 92.180     NaN   NaN      NaN    NaN
# 2008     NaN   NaN      NaN    NaN    NaN     NaN   NaN      NaN    NaN
# 2009     NaN   NaN      NaN    NaN    NaN     NaN   NaN      NaN    NaN
# 2010     NaN   NaN      NaN    NaN    NaN  39.660   NaN      NaN    NaN
#
# Name   엔스퍼트  영우디에스피  오성첨단소재  완리    우리넷  우리로  원익  웨이브일렉트로  위메이드  유니테스트   유진테크  \
# year
# 2006    NaN     NaN     NaN NaN    NaN  NaN NaN      NaN   NaN    NaN 48.400
# 2007    NaN     NaN     NaN NaN    NaN  NaN NaN      NaN   NaN 63.830    NaN
# 2008 73.670     NaN     NaN NaN    NaN  NaN NaN   38.860   NaN    NaN    NaN
# 2009    NaN     NaN  47.080 NaN    NaN  NaN NaN      NaN   NaN    NaN    NaN
# 2010    NaN     NaN     NaN NaN 40.670  NaN NaN      NaN   NaN    NaN    NaN
#
# Name  이노와이어리스  이디디컴퍼니   이미지스   이아이디  인터불스  인터파크홀딩스   인포바인   인포피아  잇츠한불  제닉  \
# year
# 2006   46.500     NaN    NaN    NaN   NaN      NaN    NaN    NaN   NaN NaN
# 2007      NaN     NaN    NaN    NaN   NaN      NaN    NaN    NaN   NaN NaN
# 2008      NaN     NaN    NaN 39.900   NaN      NaN    NaN 43.910   NaN NaN
# 2009      NaN     NaN    NaN    NaN   NaN      NaN    NaN    NaN   NaN NaN
# 2010      NaN     NaN 42.520    NaN   NaN      NaN 42.220    NaN   NaN NaN
#
# Name    제우스  제주반도체   조이맥스  종근당홀딩스  지디  지스마트글로벌  컴투스  코라오홀딩스  클리오  키위미디어그룹  \
# year
# 2006 41.020 41.640    NaN     NaN NaN      NaN  NaN     NaN  NaN      NaN
# 2007    NaN    NaN    NaN     NaN NaN      NaN  NaN     NaN  NaN      NaN
# 2008    NaN    NaN    NaN     NaN NaN      NaN  NaN     NaN  NaN      NaN
# 2009    NaN    NaN    NaN     NaN NaN      NaN  NaN     NaN  NaN      NaN
# 2010    NaN    NaN 63.530     NaN NaN   45.940  NaN     NaN  NaN      NaN
#
# Name  키이스트  태산엘시디  테라리소스     테스   티엘아이  티이씨앤코  포시에스   플랜티넷  피엘에이  하이로닉  \
# year
# 2006   NaN    NaN    NaN    NaN    NaN    NaN   NaN 51.440   NaN   NaN
# 2007   NaN    NaN    NaN    NaN 45.410    NaN   NaN    NaN   NaN   NaN
# 2008   NaN    NaN    NaN    NaN    NaN    NaN   NaN    NaN   NaN   NaN
# 2009   NaN    NaN    NaN 37.050    NaN    NaN   NaN    NaN   NaN   NaN
# 2010   NaN    NaN 41.200    NaN    NaN    NaN   NaN    NaN   NaN   NaN
#
# Name  하이비젼시스템  한국가구   한국주강  한국타이어월드와이드  한솔로지스틱스  한화화인케미칼  현대시멘트  현대페인트  \
# year
# 2006      NaN   NaN    NaN         NaN      NaN      NaN    NaN    NaN
# 2007      NaN   NaN    NaN         NaN      NaN      NaN    NaN    NaN
# 2008      NaN   NaN    NaN         NaN      NaN      NaN    NaN    NaN
# 2009      NaN   NaN 45.080         NaN      NaN   35.860    NaN    NaN
# 2010      NaN   NaN    NaN         NaN      NaN      NaN    NaN    NaN
#
# Name  현대하이스코  화신테크  휴메딕스
# year
# 2006     NaN   NaN   NaN
# 2007     NaN   NaN   NaN
# 2008     NaN   NaN   NaN
# 2009     NaN   NaN   NaN
# 2010     NaN   NaN   NaN

# %% [markdown]
# - 주의: nan 값을 가지고 있는 종목은 아예 고려대상에서 배제됨(물론 agg 함수의 연산특성에 따라 다르기는하나, 대부분의 함수가 nan은 배제시키고 계산함)
# - 깜짝 퀴즈
#     - 각 row별, nan이 아닌 값이 정확히 top_n개 만큼 인지 확인하는 방법?

# %% [markdown]
# ## backtest

# %%
indicator_df.head()
# Out:
# Name    DMS  GKL    ISC  KG이니시스  MP한강  NAVER  S&K폴리텍     SY  골프존뉴딘   나노캠텍  \
# year
# 2006 45.300  NaN    NaN     NaN   NaN    NaN     NaN    NaN    NaN    NaN
# 2007    NaN  NaN    NaN  46.090   NaN    NaN     NaN 34.510    NaN 35.540
# 2008    NaN  NaN 47.170     NaN   NaN    NaN  36.670    NaN    NaN    NaN
# 2009    NaN  NaN    NaN     NaN   NaN 41.180     NaN    NaN    NaN    NaN
# 2010    NaN  NaN    NaN     NaN   NaN 40.050     NaN    NaN    NaN    NaN
#
# Name  나노트로닉스  내츄럴엔도텍  네이쳐글로벌  넥스트리밍  넥스트바이오홀딩스  넥스트아이   넥스트칩  다믈멀티미디어  더블유게임즈  \
# year
# 2006     NaN     NaN     NaN    NaN        NaN    NaN    NaN      NaN     NaN
# 2007     NaN     NaN  42.310    NaN     45.110    NaN    NaN      NaN     NaN
# 2008     NaN     NaN     NaN    NaN        NaN    NaN 39.530   39.340     NaN
# 2009  38.390     NaN     NaN    NaN     45.910    NaN    NaN      NaN     NaN
# 2010     NaN     NaN     NaN    NaN        NaN    NaN    NaN      NaN     NaN
#
# Name  동양  동양네트웍스   디엔에프  디지텍시스템  라이온켐텍  루미마이크로  메지온  모다    모린스  미동앤씨네마  보해양조  \
# year
# 2006 NaN     NaN    NaN     NaN    NaN  58.550  NaN NaN    NaN     NaN   NaN
# 2007 NaN     NaN    NaN     NaN    NaN     NaN  NaN NaN    NaN     NaN   NaN
# 2008 NaN     NaN 45.310  48.830    NaN     NaN  NaN NaN    NaN     NaN   NaN
# 2009 NaN     NaN    NaN     NaN    NaN     NaN  NaN NaN    NaN     NaN   NaN
# 2010 NaN     NaN    NaN     NaN    NaN     NaN  NaN NaN 53.790     NaN   NaN
#
# Name  부방    뷰웍스  비아트론  사파이어테크놀로지  삼성바이오로직스   서호전기  선데이토즈  성지건설  성창기업지주  \
# year
# 2006 NaN    NaN   NaN        NaN       NaN    NaN    NaN   NaN     NaN
# 2007 NaN    NaN   NaN        NaN       NaN    NaN    NaN   NaN     NaN
# 2008 NaN    NaN   NaN        NaN       NaN    NaN    NaN   NaN     NaN
# 2009 NaN 35.490   NaN        NaN       NaN    NaN    NaN   NaN     NaN
# 2010 NaN    NaN   NaN        NaN       NaN 41.980    NaN   NaN     NaN
#
# Name  셀트리온제약  슈프리마에이치큐  슈피겐코리아  시너지이노베이션  신세계  썸에이지    씨모텍  씨엘인터내셔널  씨젠  \
# year
# 2006     NaN       NaN     NaN    64.490  NaN   NaN    NaN      NaN NaN
# 2007  36.900       NaN     NaN       NaN  NaN   NaN    NaN   41.620 NaN
# 2008     NaN       NaN     NaN       NaN  NaN   NaN    NaN      NaN NaN
# 2009     NaN    36.270     NaN       NaN  NaN   NaN 39.120      NaN NaN
# 2010     NaN       NaN     NaN       NaN  NaN   NaN    NaN      NaN NaN
#
# Name  씨케이에이치  아나패스  아이디스홀딩스  아이디에스  아이즈비전  아트라스BX  앤디포스  에스디생명공학   에스엔유  \
# year
# 2006     NaN   NaN      NaN 43.560    NaN     NaN   NaN      NaN 62.610
# 2007     NaN   NaN      NaN    NaN 92.180     NaN   NaN      NaN    NaN
# 2008     NaN   NaN      NaN    NaN    NaN     NaN   NaN      NaN    NaN
# 2009     NaN   NaN      NaN    NaN    NaN     NaN   NaN      NaN    NaN
# 2010     NaN   NaN      NaN    NaN    NaN  39.660   NaN      NaN    NaN
#
# Name   엔스퍼트  영우디에스피  오성첨단소재  완리    우리넷  우리로  원익  웨이브일렉트로  위메이드  유니테스트   유진테크  \
# year
# 2006    NaN     NaN     NaN NaN    NaN  NaN NaN      NaN   NaN    NaN 48.400
# 2007    NaN     NaN     NaN NaN    NaN  NaN NaN      NaN   NaN 63.830    NaN
# 2008 73.670     NaN     NaN NaN    NaN  NaN NaN   38.860   NaN    NaN    NaN
# 2009    NaN     NaN  47.080 NaN    NaN  NaN NaN      NaN   NaN    NaN    NaN
# 2010    NaN     NaN     NaN NaN 40.670  NaN NaN      NaN   NaN    NaN    NaN
#
# Name  이노와이어리스  이디디컴퍼니   이미지스   이아이디  인터불스  인터파크홀딩스   인포바인   인포피아  잇츠한불  제닉  \
# year
# 2006   46.500     NaN    NaN    NaN   NaN      NaN    NaN    NaN   NaN NaN
# 2007      NaN     NaN    NaN    NaN   NaN      NaN    NaN    NaN   NaN NaN
# 2008      NaN     NaN    NaN 39.900   NaN      NaN    NaN 43.910   NaN NaN
# 2009      NaN     NaN    NaN    NaN   NaN      NaN    NaN    NaN   NaN NaN
# 2010      NaN     NaN 42.520    NaN   NaN      NaN 42.220    NaN   NaN NaN
#
# Name    제우스  제주반도체   조이맥스  종근당홀딩스  지디  지스마트글로벌  컴투스  코라오홀딩스  클리오  키위미디어그룹  \
# year
# 2006 41.020 41.640    NaN     NaN NaN      NaN  NaN     NaN  NaN      NaN
# 2007    NaN    NaN    NaN     NaN NaN      NaN  NaN     NaN  NaN      NaN
# 2008    NaN    NaN    NaN     NaN NaN      NaN  NaN     NaN  NaN      NaN
# 2009    NaN    NaN    NaN     NaN NaN      NaN  NaN     NaN  NaN      NaN
# 2010    NaN    NaN 63.530     NaN NaN   45.940  NaN     NaN  NaN      NaN
#
# Name  키이스트  태산엘시디  테라리소스     테스   티엘아이  티이씨앤코  포시에스   플랜티넷  피엘에이  하이로닉  \
# year
# 2006   NaN    NaN    NaN    NaN    NaN    NaN   NaN 51.440   NaN   NaN
# 2007   NaN    NaN    NaN    NaN 45.410    NaN   NaN    NaN   NaN   NaN
# 2008   NaN    NaN    NaN    NaN    NaN    NaN   NaN    NaN   NaN   NaN
# 2009   NaN    NaN    NaN 37.050    NaN    NaN   NaN    NaN   NaN   NaN
# 2010   NaN    NaN 41.200    NaN    NaN    NaN   NaN    NaN   NaN   NaN
#
# Name  하이비젼시스템  한국가구   한국주강  한국타이어월드와이드  한솔로지스틱스  한화화인케미칼  현대시멘트  현대페인트  \
# year
# 2006      NaN   NaN    NaN         NaN      NaN      NaN    NaN    NaN
# 2007      NaN   NaN    NaN         NaN      NaN      NaN    NaN    NaN
# 2008      NaN   NaN    NaN         NaN      NaN      NaN    NaN    NaN
# 2009      NaN   NaN 45.080         NaN      NaN   35.860    NaN    NaN
# 2010      NaN   NaN    NaN         NaN      NaN      NaN    NaN    NaN
#
# Name  현대하이스코  화신테크  휴메딕스
# year
# 2006     NaN   NaN   NaN
# 2007     NaN   NaN   NaN
# 2008     NaN   NaN   NaN
# 2009     NaN   NaN   NaN
# 2010     NaN   NaN   NaN

# %% [markdown]
# ### 포트폴리오 수익률 데이터

# %%
asset_on_df = indicator_df.notna().astype(int).replace(0, np.nan)
asset_on_df.head()
# Out:
# Name   DMS  GKL   ISC  KG이니시스  MP한강  NAVER  S&K폴리텍    SY  골프존뉴딘  나노캠텍  나노트로닉스  \
# year
# 2006 1.000  NaN   NaN     NaN   NaN    NaN     NaN   NaN    NaN   NaN     NaN
# 2007   NaN  NaN   NaN   1.000   NaN    NaN     NaN 1.000    NaN 1.000     NaN
# 2008   NaN  NaN 1.000     NaN   NaN    NaN   1.000   NaN    NaN   NaN     NaN
# 2009   NaN  NaN   NaN     NaN   NaN  1.000     NaN   NaN    NaN   NaN   1.000
# 2010   NaN  NaN   NaN     NaN   NaN  1.000     NaN   NaN    NaN   NaN     NaN
#
# Name  내츄럴엔도텍  네이쳐글로벌  넥스트리밍  넥스트바이오홀딩스  넥스트아이  넥스트칩  다믈멀티미디어  더블유게임즈  동양  \
# year
# 2006     NaN     NaN    NaN        NaN    NaN   NaN      NaN     NaN NaN
# 2007     NaN   1.000    NaN      1.000    NaN   NaN      NaN     NaN NaN
# 2008     NaN     NaN    NaN        NaN    NaN 1.000    1.000     NaN NaN
# 2009     NaN     NaN    NaN      1.000    NaN   NaN      NaN     NaN NaN
# 2010     NaN     NaN    NaN        NaN    NaN   NaN      NaN     NaN NaN
#
# Name  동양네트웍스  디엔에프  디지텍시스템  라이온켐텍  루미마이크로  메지온  모다   모린스  미동앤씨네마  보해양조  부방  \
# year
# 2006     NaN   NaN     NaN    NaN   1.000  NaN NaN   NaN     NaN   NaN NaN
# 2007     NaN   NaN     NaN    NaN     NaN  NaN NaN   NaN     NaN   NaN NaN
# 2008     NaN 1.000   1.000    NaN     NaN  NaN NaN   NaN     NaN   NaN NaN
# 2009     NaN   NaN     NaN    NaN     NaN  NaN NaN   NaN     NaN   NaN NaN
# 2010     NaN   NaN     NaN    NaN     NaN  NaN NaN 1.000     NaN   NaN NaN
#
# Name   뷰웍스  비아트론  사파이어테크놀로지  삼성바이오로직스  서호전기  선데이토즈  성지건설  성창기업지주  셀트리온제약  \
# year
# 2006   NaN   NaN        NaN       NaN   NaN    NaN   NaN     NaN     NaN
# 2007   NaN   NaN        NaN       NaN   NaN    NaN   NaN     NaN   1.000
# 2008   NaN   NaN        NaN       NaN   NaN    NaN   NaN     NaN     NaN
# 2009 1.000   NaN        NaN       NaN   NaN    NaN   NaN     NaN     NaN
# 2010   NaN   NaN        NaN       NaN 1.000    NaN   NaN     NaN     NaN
#
# Name  슈프리마에이치큐  슈피겐코리아  시너지이노베이션  신세계  썸에이지   씨모텍  씨엘인터내셔널  씨젠  씨케이에이치  아나패스  \
# year
# 2006       NaN     NaN     1.000  NaN   NaN   NaN      NaN NaN     NaN   NaN
# 2007       NaN     NaN       NaN  NaN   NaN   NaN    1.000 NaN     NaN   NaN
# 2008       NaN     NaN       NaN  NaN   NaN   NaN      NaN NaN     NaN   NaN
# 2009     1.000     NaN       NaN  NaN   NaN 1.000      NaN NaN     NaN   NaN
# 2010       NaN     NaN       NaN  NaN   NaN   NaN      NaN NaN     NaN   NaN
#
# Name  아이디스홀딩스  아이디에스  아이즈비전  아트라스BX  앤디포스  에스디생명공학  에스엔유  엔스퍼트  영우디에스피  \
# year
# 2006      NaN  1.000    NaN     NaN   NaN      NaN 1.000   NaN     NaN
# 2007      NaN    NaN  1.000     NaN   NaN      NaN   NaN   NaN     NaN
# 2008      NaN    NaN    NaN     NaN   NaN      NaN   NaN 1.000     NaN
# 2009      NaN    NaN    NaN     NaN   NaN      NaN   NaN   NaN     NaN
# 2010      NaN    NaN    NaN   1.000   NaN      NaN   NaN   NaN     NaN
#
# Name  오성첨단소재  완리   우리넷  우리로  원익  웨이브일렉트로  위메이드  유니테스트  유진테크  이노와이어리스  이디디컴퍼니  \
# year
# 2006     NaN NaN   NaN  NaN NaN      NaN   NaN    NaN 1.000    1.000     NaN
# 2007     NaN NaN   NaN  NaN NaN      NaN   NaN  1.000   NaN      NaN     NaN
# 2008     NaN NaN   NaN  NaN NaN    1.000   NaN    NaN   NaN      NaN     NaN
# 2009   1.000 NaN   NaN  NaN NaN      NaN   NaN    NaN   NaN      NaN     NaN
# 2010     NaN NaN 1.000  NaN NaN      NaN   NaN    NaN   NaN      NaN     NaN
#
# Name  이미지스  이아이디  인터불스  인터파크홀딩스  인포바인  인포피아  잇츠한불  제닉   제우스  제주반도체  조이맥스  \
# year
# 2006   NaN   NaN   NaN      NaN   NaN   NaN   NaN NaN 1.000  1.000   NaN
# 2007   NaN   NaN   NaN      NaN   NaN   NaN   NaN NaN   NaN    NaN   NaN
# 2008   NaN 1.000   NaN      NaN   NaN 1.000   NaN NaN   NaN    NaN   NaN
# 2009   NaN   NaN   NaN      NaN   NaN   NaN   NaN NaN   NaN    NaN   NaN
# 2010 1.000   NaN   NaN      NaN 1.000   NaN   NaN NaN   NaN    NaN 1.000
#
# Name  종근당홀딩스  지디  지스마트글로벌  컴투스  코라오홀딩스  클리오  키위미디어그룹  키이스트  태산엘시디  테라리소스  \
# year
# 2006     NaN NaN      NaN  NaN     NaN  NaN      NaN   NaN    NaN    NaN
# 2007     NaN NaN      NaN  NaN     NaN  NaN      NaN   NaN    NaN    NaN
# 2008     NaN NaN      NaN  NaN     NaN  NaN      NaN   NaN    NaN    NaN
# 2009     NaN NaN      NaN  NaN     NaN  NaN      NaN   NaN    NaN    NaN
# 2010     NaN NaN    1.000  NaN     NaN  NaN      NaN   NaN    NaN  1.000
#
# Name    테스  티엘아이  티이씨앤코  포시에스  플랜티넷  피엘에이  하이로닉  하이비젼시스템  한국가구  한국주강  \
# year
# 2006   NaN   NaN    NaN   NaN 1.000   NaN   NaN      NaN   NaN   NaN
# 2007   NaN 1.000    NaN   NaN   NaN   NaN   NaN      NaN   NaN   NaN
# 2008   NaN   NaN    NaN   NaN   NaN   NaN   NaN      NaN   NaN   NaN
# 2009 1.000   NaN    NaN   NaN   NaN   NaN   NaN      NaN   NaN 1.000
# 2010   NaN   NaN    NaN   NaN   NaN   NaN   NaN      NaN   NaN   NaN
#
# Name  한국타이어월드와이드  한솔로지스틱스  한화화인케미칼  현대시멘트  현대페인트  현대하이스코  화신테크  휴메딕스
# year
# 2006         NaN      NaN      NaN    NaN    NaN     NaN   NaN   NaN
# 2007         NaN      NaN      NaN    NaN    NaN     NaN   NaN   NaN
# 2008         NaN      NaN      NaN    NaN    NaN     NaN   NaN   NaN
# 2009         NaN      NaN    1.000    NaN    NaN     NaN   NaN   NaN
# 2010         NaN      NaN      NaN    NaN    NaN     NaN   NaN   NaN

# %%
# 지난 영상 퀴즈 정답1
yearly_rtn_df.shape
asset_on_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # 지난 영상 퀴즈 정답1
# ----> 2 yearly_rtn_df.shape
#       3 asset_on_df.shape
#
# NameError: name 'yearly_rtn_df' is not defined

# %%
# 지난 영상 퀴즈 정답2
asset_on_df.notna().sum(axis=1)
# Out:
# year
# 2006    10
# 2007    10
# 2008    10
# 2009    10
# 2010    10
# 2011    10
# 2012    10
# 2013    10
# 2014    10
# 2015    10
# 2016    10
# 2017    10
# dtype: int64

# %%
selected_return_df = yearly_rtn_df * asset_on_df
selected_return_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 selected_return_df = yearly_rtn_df * asset_on_df
#       2 selected_return_df.head()
#
# NameError: name 'yearly_rtn_df' is not defined

# %%
selected_return_df.notna().sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 selected_return_df.notna().sum(axis=1)
#
# NameError: name 'selected_return_df' is not defined

# %%
a = asset_on_df.iloc[0]
a[a.notna()]
# Out:
# Name
# DMS        1.000
# 루미마이크로     1.000
# 시너지이노베이션   1.000
# 아이디에스      1.000
# 에스엔유       1.000
# 유진테크       1.000
# 이노와이어리스    1.000
# 제우스        1.000
# 제주반도체      1.000
# 플랜티넷       1.000
# Name: 2006, dtype: float64

# %%
b = yearly_rtn_df.iloc[0]
b[a[a.notna()].index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 b = yearly_rtn_df.iloc[0]
#       2 b[a[a.notna()].index]
#
# NameError: name 'yearly_rtn_df' is not defined

# %%
rtn_series = selected_return_df.mean(axis=1)
rtn_series.head()

# %%
# 새로 수정된 데이터(fin_statement_new.csv)에서는 데이터 2006부터 시작하므로, 2005를 0으로 설정한 점에 주의바랍니다.
rtn_series.loc[2005] = 0
rtn_series = rtn_series.sort_index()
rtn_series

# %% [markdown]
# ### 포트폴리오 누적 수익률 데이터

# %%
cum_rtn_series = (rtn_series + 1).cumprod().dropna()
cum_rtn_series

# %%
pd.Series([1,2,3,4,5]).cumsum()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
 
fig, axes = plt.subplots(nrows=2, figsize=(15, 6), sharex=True)

axes[0].plot(cum_rtn_series.index, cum_rtn_series, marker='o');
axes[0].set_title("Cum return(line)");

axes[1].bar(rtn_series.index, rtn_series);
axes[1].set_title("Yearly return(bar)");

# %% [markdown]
# ## 함수화

# %%
def get_return_series(selected_return_df):
    rtn_series = selected_return_df.mean(axis=1)
    rtn_series.loc[2005] = 0     # 주의: 영상속의 데이터와는 달리, 새로 업로드 된 데이터는 2006부터 존재하므로
                                 # 2004가 아니라 2005를 0으로 설정한 점에 주의해주세요
    rtn_series = rtn_series.sort_index()

    cum_rtn_series = (rtn_series + 1).cumprod().dropna()
    return rtn_series, cum_rtn_series

# %%
def plot_return(cum_rtn_series, rtn_series):
    fig, axes = plt.subplots(nrows=2, figsize=(15, 6), sharex=True)
    axes[0].plot(cum_rtn_series.index, cum_rtn_series, marker='o');
    axes[1].bar(rtn_series.index, rtn_series);
    axes[0].set_title("Cum return(line)");
    axes[1].set_title("Yearly return(bar)");

# %%
rtn_series, cum_rtn_series = get_return_series(selected_return_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 rtn_series, cum_rtn_series = get_return_series(selected_return_df)
#
# NameError: name 'selected_return_df' is not defined

# %%
plot_return(cum_rtn_series, rtn_series)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 plot_return(cum_rtn_series, rtn_series)
#
# NameError: name 'cum_rtn_series' is not defined

# %% [markdown]
# ## quantile (e.g. 상위 n% 종목 선정)

# %%
quantile_by_year_series = df.groupby(['year'])[indicator].quantile(0.9)
quantile_by_year_series

# %%
quantilie_indicator_df = df.join(quantile_by_year_series, how="left", on="year", rsuffix="_quantile")
quantilie_indicator_df.head(2)

# %%
quantilie_indicator_df = quantilie_indicator_df[
    quantilie_indicator_df[indicator] >= quantilie_indicator_df["{}_quantile".format(indicator)]
]
quantilie_indicator_df.head()

# %%
quantilie_indicator_df.groupby('year')['Code'].count()

# %%
indicator_df = quantilie_indicator_df.pivot(index='year', columns="Name", values=indicator)
asset_on_df = indicator_df.notna().astype(int).replace(0, np.nan)

# %%
selected_return_df = yearly_rtn_df * asset_on_df
selected_return_df.head()

# %%
rtn_series, cum_rtn_series = get_return_series(selected_return_df)
plot_return(cum_rtn_series, rtn_series)

# %% [markdown]
# # 강환국님의 "할수있다 퀀트투자" 구현해보기

# %% [markdown]
# ![](http://image.kyobobook.co.kr/images/book/large/392/l9791195887392.jpg)

# %% [markdown]
# ## quantile + top10

# %% [markdown]
# - Filter + Selector 구조
#     - Filter
#         - e.g. 부채비율 0.5이상
#         - 최종 포트폴리오 종목 갯수 선정에 직접적으로 영향 X
#     - Selector
#         - 최종적으로 xx개의 종목이 선택의 기준이 되는 indicator
#         - e.g. PBR이 0.2 이상인 회사 중에 가장 낮은 순으로 20~30개 매수

# %% [markdown]
# - zipline (https://github.com/quantopian/zipline)

# %% [markdown]
# ## [Chapter 6] 투자전략22. 소형주 + 저PBR 전략(200p)

# %% [markdown]
# - Filter
#     - 소형주(시가총액 하위 20%)
#
# - Select
#     - PBR 0.2 이상
#     - PBR이 가장 낮은 주식순으로 20~30개 매수

# %%
#
# Filter
#
market_cap_quantile_series = df.groupby("year")['시가총액'].quantile(.2)

filtered_df = df.join(market_cap_quantile_series, on="year", how="left", rsuffix="20%_quantile")
filtered_df = filtered_df[filtered_df['시가총액'] <= filtered_df['시가총액20%_quantile']]
filtered_df.head()

# %%
#
# Selector
#
filtered_df = filtered_df[filtered_df['PBR'] >= 0.2]

smallest_pbr_series = filtered_df.groupby("year")['PBR'].nsmallest(15)
smallest_pbr_series

# %%
selected_index = smallest_pbr_series.index.get_level_values(1)

selector_df = filtered_df.loc[selected_index].pivot(
    index='year', columns="Name", values="PBR"
)
selector_df.head()

# %%
asset_on_df = selector_df.notna().astype(int).replace(0, np.nan)
selected_return_df = yearly_rtn_df * asset_on_df

# %%
rtn_series, cum_rtn_series = get_return_series(selected_return_df)
plot_return(cum_rtn_series, rtn_series)

# %% [markdown]
# ## [Chapter 5] 투자전략20. 그레이엄의 마지막선물 업그레이드(188p)

# %% [markdown]
# - Filter
#     - ROA 5% 이상
#     - 부채비율 50% 이하
# - Select
#     - (PBR 0.2 이상)
#     - PBR 낮은기업 20~30개 매수

# %%
#
# Filter
#

# ROA >= 0.05
filtered_df = df[df['ROA'] >= 0.05]

# 부채비율 <= 0.5
filtered_df['부채비율'] = filtered_df['비유동부채'] / filtered_df['자산총계']
filtered_df = filtered_df[filtered_df['부채비율'] <= 0.5]

# %%
#
# Selector(위의 투자전략22 것 그대로)
#
filtered_df = filtered_df[filtered_df['PBR'] >= 0.2]

smallest_pbr_series = filtered_df.groupby("year")['PBR'].nsmallest(15)
selected_index = smallest_pbr_series.index.get_level_values(1)

selector_df = filtered_df.loc[selected_index].pivot(
    index='year', columns="Name", values="PBR"
)

# %%
asset_on_df = selector_df.notna().astype(int).replace(0, np.nan)
selected_return_df = yearly_rtn_df * asset_on_df

# %%
rtn_series, cum_rtn_series = get_return_series(selected_return_df)
plot_return(cum_rtn_series, rtn_series)

# %% [markdown]
# ## [Chapter 8] 투자전략24. 슈퍼가치전략(246p)

# %% [markdown]
# - Filter
#     - 시가총액 하위 20%
# - Selector
#     - PBR, PCR, PER, PSR 순위를 매김
#     - 각 순위를 sum을 해서 통합순위를 구함
#     - 통합순위가 가장 높은 종목 50개 매수

# %%
#
# Filter
#
market_cap_quantile_series = df.groupby("year")['시가총액'].quantile(.2)
filtered_df = df.join(market_cap_quantile_series, on="year", how="left", rsuffix="20%_quantile")
filtered_df = filtered_df[filtered_df['시가총액'] <= filtered_df['시가총액20%_quantile']]

# %%
pd.Series([100, 1, 1, 3]).rank(method="max")
pd.Series([100, 1, 1, 3]).rank(method="min")

# %%
pbr_rank_series = filtered_df.groupby("year")['PBR'].rank(method="max")
per_rank_series = filtered_df.groupby("year")['PER'].rank(method="max")
psr_rank_series = filtered_df.groupby("year")['PSR'].rank(method="max")

# %%
psr_rank_series.head()

# %%
psr_rank_series.sort_values().dropna().head()

# %%
filtered_df = filtered_df.join(pbr_rank_series, how="left", rsuffix="_rank")
filtered_df = filtered_df.join(per_rank_series, how="left", rsuffix="_rank")
filtered_df = filtered_df.join(psr_rank_series, how="left", rsuffix="_rank")

# %%
filtered_df['PBR_rank'].isna().sum()

# %% [markdown]
# - 어떻게 각 rank column의 nan을 메꿔야할까?

# %%
filtered_df.filter(like="rank").columns

# %%
#
# 주의: 종목을 선택하는 로직ㅇ[ 따라, '가장 작은 rank'로 부여하는게 타당할 수도 있고, '가장 큰 rank'로 부여하는 것이 타당할 수도 있습니다.
# 예를들어, PER이 작을수록 종목 선정에 우선 순위가 있도록 할 예정이고, PER이 작을수록 rank값이 작도록 설정했다면,
# PER이 nan인 종목들은 PER rank가 가장 큰 값(혹은 그 값보다 +1인 값)으로 메꿔져야 penalty를 받을 수 있습니다.
#

# 1. 0으로 메꾸는 법
filtered_df.loc[:, filtered_df.filter(like="rank").columns] = filtered_df.filter(like="rank").fillna(0)

# 2. 각 rank별 max 값 (혹은 그것보다 1 큰 값)으로 메꾸는 법
# filtered_df['PBR_rank'] = filtered_df['PBR_rank'].fillna(filtered_df['PBR_rank'].max() + 1)
# filtered_df['PER_rank'] = filtered_df['PER_rank'].fillna(filtered_df['PER_rank'].max() + 1)
# filtered_df['PSR_rank'] = filtered_df['PSR_rank'].fillna(filtered_df['PSR_rank'].max() + 1)

# %%
filtered_df['rank_sum'] = filtered_df.filter(like="_rank").sum(axis=1)

# %%
#
# Selector
#
max_rank_series = filtered_df.groupby("year")['rank_sum'].nlargest(15)
selected_index = max_rank_series.index.get_level_values(1)

selector_df = filtered_df.loc[selected_index].pivot(
    index='year', columns="Name", values="rank_sum"
)

# %%
asset_on_df = selector_df.notna().astype(int).replace(0, np.nan)
selected_return_df = yearly_rtn_df * asset_on_df

# %%
rtn_series, cum_rtn_series = get_return_series(selected_return_df)
plot_return(cum_rtn_series, rtn_series)

# %% [markdown]
# # 재무제표 기반 실전 프로젝트의 한계

# %% [markdown]
# - **(중요)Look ahead bias & Survivalship bias**
#     - 특정 년도에 상장이 폐지가 되었다면 -> 바로 이전 년도에서 종목선정에 고려가 안됨
#     - 즉, 이미 상장 폐지 정보를 미래 시점에서 확인하고, 해당 년도의 수익률을 nan으로 미리 메꾸어 버림
# - Data availability(time alignment)
#     - 각 투자지표의 값들이 공시 되는 시기
#         - 년도별, 분기별
#     - 정확한 상장폐지 날짜?
# - Data acquisition
#     - 고정된 과거데이터로만 테스트 하면 안됨 -> 계속 새로운 데이터에 대한 갱신 필요
#     - 크롤링, 증권사 API, 유료 데이터 벤더 등
# - Data의 무결성
#     - 아무리 증권사 API나 유로 벤더를 통해서 받아온 데이터라도, 문제가 있는 경우가 많음
#     - 예를 들어, 일봉 OHLC -> C가 H보다 더 큰 경우 / 배당락, 주식분할 등의 이벤트가 제대로 반영이 안된 경우 등
#     - 데이터의 결함, nunique==1, 비이상적인 값 등에 대한 EDA 필요
# - 데이터가 년도별로만 존재하기 때문에, 1년에 한번 수익률이 찍혀서 변동성, MDD를 제대로 파악하기 어려움
# - 거래세, 수수료 반영 X
#     - 정확한 asset turnover 고려가 안됨
# - 기타 위 실전예제에서의 한계
#     - 데이터의 cleaning, validation 필요
#     - Missing value에 대한 전처리 필요
#     - 주어진 데이터 존재하지 않는 지표(column)은 다른 지표로 대체한 점

# %% [markdown]
# # 혼자 진행해보면 좋을 것들

# %% [markdown]
# - `transform()`, `apply()` 함수 등을 구글링해서 독학해보기
# - OOP 방식으로 구현해보기(확장성 있는 코드화)

# %%
filter_list = [
    ColumnIndicator("부채비율", 0.5, lower_than=False),
    ColumnIndicator("ROE", 0.5, lower_than=True),
]
selector = Selector("PBR", 20, lowest=True)

backtest = Backtest(filter_list, selector, yearly_rtn_df)
backtest.run()

# %% [markdown]
# - 거래비용 주기

# %%
for_positive_df = (yearly_rtn_df > 0).astype(int) * 0.99
for_negative_df = (yearly_rtn_df < 0).astype(int) * 1.01

extra_fee_considered_weight_df = for_positive_df + for_negative_df
yearly_rtn_df = yearly_rtn_df * extra_fee_considered_weight_df

# %% [markdown]
# - weight
#     - 지금까지는 종목 선택 후, 다 동일가중 투자(`mean()`만으로 평균수익률을 구할 수 있었음)
#     - e.g. ROA의 비중만큼 넣기
#         - Top n개의 종목을 산출 후, 각각의 값을 1,0(nan)으로 변환하기 전에, `selector_df`를 sum(axis=1)로 나눠주기 등
#
# - 분기별 데이터 & 리벨런싱

# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import logging
import platform
df = fdr.StockListing('KRX')

# %%
df

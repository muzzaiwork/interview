# %% [markdown]
# # 수업에 사용될 라이브러리 설치

# %%
# !ls   # 윈도우 사용자# 의 경우 -> dir
# Out:
# 00_넘파이_기초_및_배열_연산_요약.md
# 01_판다스_핵심_객체_Series_및_DataFrame_요약.md
# 02_판다스_EDA_및_데이터_분석_기초_요약.md
# 03_판다스_데이터_범주화_및_그룹화_요약.md
# 04_판다스_데이터_결합_및_병합_요약.md
# 05_판다스_및_시각화_라이브러리_활용_요약.md
# 06_재무제표_기반_퀀트_백테스팅_실전_요약.md
# 07_강의_마무리_및_향후_학습_안내_요약.md
# 08_시계열_데이터_기초_및_인덱스_활용_요약.md
# 09_수익률_계산_및_로그_수익률의_이해_요약.md
# 10_금융_성과_지표_CAGR_Sharpe_MDD_요약.md
# 11_이동평균_및_변동성_지표_활용_요약.md
# 12_시그널_기반_백테스팅_전략_구현_요약.md
# 13_데이터_빈도_변환_및_리샘플링_요약.md
# 14_리밸런싱_기반_백테스팅_메커니즘_요약.md
# 15_포트폴리오_자산배분_전략_실전_요약.md
# data
# guide.md
# lec1_0_intro_to_numpy_ForOnlineLecture.ipynb
# lec1_1_Basics_of_DataFrame_and_Series_ForOnlineLecture.ipynb
# lec1_2_EDA_with_fin_statement_ForOnelineLecture.ipynb
# lec1_3_Categorizing_and_Groupby_ForOnelineLecture.ipynb
# lec1_4_Combining_Pandas_Objects_ForOnlineLecture.ipynb
# lec1_5_visualization_ForOnelineLecture.ipynb
# lec1_6_project_ForOnlineLecture.ipynb
# lec1_7_wrapup_ForOnlineLecture.ipynb
# lec2_1_timeindex_ForOnlinelecture.ipynb
# lec2_2_more_about_returns_ForOnlinelecture.ipynb
# lec2_3_performance_indicator_ForOnlineLecture.ipynb
# lec2_4_price_based_indicator_ForOnlineLecture.ipynb
# lec2_5_signal_based_backtesting_ForOnlineLecture.ipynb
# lec2_6_freq_conversion_ForOnlineLecture.ipynb
# lec2_7_rebalancing_based_backtesting_ForOnlineLecture.ipynb
# lec2_8_practice_ForOnlineLecture.ipynb
# my_data
# pre_import.ipynb
# requirements.txt
# test_compatibility.py
# 미래에셋_지원용_퀀트_백엔드_모듈.py
# 실전_사이드_프로젝트_퀀트_백테스팅.py

# %%
pip install numpy

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Numpy 소개

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np

# %% [markdown]
# ## ndarray dtype

# %%
a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
# indexing이 list와 방식이 같음
a[0]
# Out:
# np.int64(1)

# %%
a.
# Out:
#   Cell In[6], line 1
#     a.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# - append() 같은 함수가 없음 -> 즉, python의 list와는 다른 data type임

# %% [markdown]
# ## Universal function

# %%
a = [1, 2, 3]
b = [4, 5, 6]

new_list = []
for e1, e2 in zip(a, b):
    new_list.append(e1 + e2)
new_list
# Out:
# [5, 7, 9]

# %%
a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# %%
# 길이가 길어도 근사적으로 1초가 걸린다
a + b
# Out:
# array([5, 7, 9])

# %%
# np.sum
# np.abs
# np.log
# np.exp
# np.isnan
# ...

# %% [markdown]
# - n차원 array

# %%
a = np.array([  [1, 2],  [3, 4]   ])
a

# %%
# readability 높이기
a = np.array(
    [
        [1, 2],
        [3, 4],
    ]
)

# %%
a[0][1]

# %%
a + a
